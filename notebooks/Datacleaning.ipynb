# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#read data
df = pd.read_csv('../data/netflix.csv')
#check data
df.head()
df.info()
df.describe()
#check for null values
df.isnull().sum()
#drop null values
df.dropna(inplace=True)
#check for duplicates
df.duplicated().sum()
#drop duplicates
df.drop_duplicates(inplace=True)
#check for outliers
sns.boxplot(x=df['release_year'])
plt.show()
#remove outliers
Q1 = df['release_year'].quantile(0.25)
Q3 = df['release_year'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['release_year'] >= lower_bound) & (df['release_year'] <= upper_bound)]
#check for duplicates
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratinglevel        941 non-null    object
#  3   ratingdescription  1000 non-null   int64
#  4   release_year       1000 non-null   int64
#  5   user_rating_score  605 non-null    float64
#  6   user_rating_size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB
# np.int64(0)

# %%
#read whole dataset after cleaning
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
#
#                                          ratinglevel  ratingdescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release_year  user_rating_score  user_rating_size
# 0          2004               82.0                80
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80
# 5          2016               95.0                80

# %%
df = pd.read_csv('../data/netflix_cleaned.csv')

# %%
#update the cleaned dataset
df.to_csv('../data/netflix_cleaned.csv', index=False)

# %%
print(df.head())
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1         Grey's Anatomy  TV-14
# 2           Prison Break  TV-14
# 3  How I Met Your Mother  TV-PG
# 4           Supernatural  TV-14
#
#                                          ratinglevel  ratingdescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  Parents strongly cautioned. May be unsuitable ...                 90
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parental guidance suggested. May not be suitab...                 70
# 4  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release_year  user_rating_score  user_rating_size  show_id
# 0          2004               82.0                80        1
# 1          2016               98.0                80        2
# 2          2008               98.0                80        3
# 3          2014               94.0                80        4
# ...

# %%
df.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1         Grey's Anatomy  TV-14
# 2           Prison Break  TV-14
# 3  How I Met Your Mother  TV-PG
# 4           Supernatural  TV-14
# 5           Breaking Bad  TV-MA
# 6    The Vampire Diaries  TV-14
# 7       The Walking Dead  TV-MA
# 8    Pretty Little Liars  TV-14
# 9       Once Upon a Time  TV-PG
#
#                                          ratinglevel  ratingdescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  Parents strongly cautioned. May be unsuitable ...                 90
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parental guidance suggested. May not be suitab...                 70
# 4  Parents strongly cautioned. May be unsuitable ...                 90
# 5  For mature audiences.  May not be suitable for...                110
# 6  Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
col = df.pop('show_id')
df.insert(0, 'show_id', col)

# %%
df.head(15)
# Out:
#     show_id                  title rating  \
# 0         1           White Chicks  PG-13
# 1         2         Grey's Anatomy  TV-14
# 2         3           Prison Break  TV-14
# 3         4  How I Met Your Mother  TV-PG
# 4         5           Supernatural  TV-14
# 5         6           Breaking Bad  TV-MA
# 6         7    The Vampire Diaries  TV-14
# 7         8       The Walking Dead  TV-MA
# 8         9    Pretty Little Liars  TV-14
# 9        10       Once Upon a Time  TV-PG
# 10       11               Sherlock  TV-14
# 11       12             Death Note  TV-14
# 12       13                 Naruto  TV-PG
# 13       14                  Arrow  TV-14
# 14       15           Black Mirror  TV-MA
#
#                                           ratinglevel  ratingdescription  \
# 0   crude and sexual humor, language and some drug...                 80
# 1   Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      show_id                  title rating  \
# 0          1           White Chicks  PG-13
# 1          2         Grey's Anatomy  TV-14
# 2          3           Prison Break  TV-14
# 3          4  How I Met Your Mother  TV-PG
# 4          5           Supernatural  TV-14
# ..       ...                    ...    ...
# 230      231         Baby's Day Out     PG
# 231      232            Blank Check     PG
# 232      233           Heavyweights     PG
# 233      234   D2: The Mighty Ducks     PG
# 234      235    H2O: Just Add Water  TV-PG
#
#                                            ratinglevel  ratingdescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    Parents strongly cautioned. May be unsuitable ...                 90
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parental guidance suggested. May not be suitab...                 70
# ...

# %%
#SHOW DATASET TITLE AND COLUMN NAMES
print(df.columns)
# Out:
# Index(['show_id', 'title', 'rating', 'ratinglevel', 'ratingdescription',
#        'release_year', 'user_rating_score', 'user_rating_size'],
#       dtype='object')
